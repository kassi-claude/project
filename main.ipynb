# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
from six.moves import urllib
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import mysql.connector as connection

# %%
download_dir ="./data/"
os.makedirs(download_dir ,exist_ok=True)
download_url="https://raw.githubusercontent.com/mohitmahiyt/CarPricePredictionDataset/main/cars_dataset.csv"
filename=os.path.basename(download_url)
print(filename)

download_file_path=os.path.join(download_dir,filename)
print(download_file_path)

urllib.request.urlretrieve(download_url,download_file_path)
# Out:
# cars_dataset.csv
# ./data/cars_dataset.csv
# ('./data/cars_dataset.csv', <http.client.HTTPMessage at 0x242d5ac7c70>)

# %%
df=pd.read_csv(r"./data/cars_dataset.csv")
df
# Out:
#        Unnamed: 0             car_name        brand        model  vehicle_age  \
# 0               1          Maruti Alto       Maruti         Alto            9
# 1               2          Maruti Alto       Maruti         Alto           11
# 2               3          Maruti Alto       Maruti         Alto           11
# 3               4          Maruti Alto       Maruti         Alto           10
# 4               5          Maruti Alto       Maruti         Alto           11
# ...           ...                  ...          ...          ...          ...
# 15406       30016  Bentley Continental      Bentley  Continental           10
# 15407       30017    Rolls-Royce Ghost  Rolls-Royce        Ghost            4
# 15408       30018  Bentley Continental      Bentley  Continental            9
# 15409       30019    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2
# 15410       30020  Bentley Continental      Bentley  Continental            9
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0          53800      Dealer       CNG            Manual    26.83     796
# 1          11000      Dealer       CNG            Manual    26.83     796
# 2          80000      Dealer       CNG            Manual    26.83     796
# 3          57000      Dealer       CNG            Manual    26.83     796
# 4          72000  Individual       CNG            Manual    26.83     796
# ...          ...         ...       ...               ...      ...     ...
# 15406      30000      Dealer    Petrol         Automatic     8.60    5998
# 15407       5000  Individual    Petrol         Automatic    10.20    6592
# 15408      37500      Dealer    Petrol         Automatic     6.00    5998
# 15409       3800      Dealer    Petrol         Automatic     4.00    3855
# 15410       9000      Dealer    Petrol         Automatic     9.50    5998
#
#        max_power  seats  selling_price
# 0           38.4      5         235000
# 1           38.4      5         185000
# 2           38.4      5         150000
# 3           38.4      5         172000
# 4           38.4      5         125000
# ...          ...    ...            ...
# 15406      552.0      4        8100000
# 15407      563.0      4       24200000
# 15408      600.0      5        5200000
# 15409      601.0      4       39500000
# 15410      626.0      4       14500000
#
# [15411 rows x 14 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0          Dealer       CNG            Manual    26.83     796       38.4
# 1          Dealer       CNG            Manual    26.83     796       38.4
# 2          Dealer       CNG            Manual    26.83     796       38.4
# 3          Dealer       CNG            Manual    26.83     796       38.4
# 4      Individual       CNG            Manual    26.83     796       38.4
# ...           ...       ...               ...      ...     ...        ...
# 15406      Dealer    Petrol         Automatic     8.60    5998      552.0
# 15407  Individual    Petrol         Automatic    10.20    6592      563.0
# 15408      Dealer    Petrol         Automatic     6.00    5998      600.0
# 15409      Dealer    Petrol         Automatic     4.00    3855      601.0
# 15410      Dealer    Petrol         Automatic     9.50    5998      626.0
#
#        seats  selling_price
# 0          5         235000
# 1          5         185000
# 2          5         150000
# 3          5         172000
# 4          5         125000
# ...      ...            ...
# 15406      4        8100000
# 15407      4       24200000
# 15408      5        5200000
# 15409      4       39500000
# 15410      4       14500000
#
# [15411 rows x 13 columns]

# %%
try:
    conn = connection.connect(user='root', password='estou123')
    query="create database if not exists car_database;"
    cursor = conn.cursor()
    cursor.execute(query)
    conn.commit()
except Exception as e:
    print(e)
else:
    print('connected')
    print("database created successfully")
finally:
    conn.close()
# Out:
# connected
# database created successfully

# %%
try:
    conn = connection.connect(user='root', password='estou123', database="car_database")
    query="""create table if not exists car_dataset(
car_name varchar(30),
brand varchar(30),
model varchar(30),
vehicle_age int,
km_driven int,
seller_type varchar(30),
fuel_type varchar(30),
transmission_type varchar(30),
mileage float,
engine int,
max_power float,
seats int,
selling_price bigint);"""

    cursor = conn.cursor()
    cursor.execute(query)
    conn.commit()
except Exception as e:
    print(e)
else:
    print('connected')
    print("table created successfully")
finally:
    conn.close()
# Out:
# connected
# table created successfully

# %%
try:
    conn = connection.connect(user='root', password='estou123', database="car_database")
    query="""truncate car_dataset;"""
    cursor = conn.cursor()
    cursor.execute(query)
    conn.commit()

    query = f"""truncate car_dataset;"""
    cursor = conn.cursor()
    cursor.execute(query)        
    conn.commit()
    for key, value in df.iterrows():
        car_name,brand,model,vehicle_age,km_driven,seller_type,fuel_type,transmission_type,mileage,engine,max_power,seats,selling_price = value[0],value[1], value[2], value[3], value[4],value[5] ,value[6],value[7] ,value[8] ,value[9] ,value[10] ,value[11] ,value[12] 
        
        query = f"""insert into car_dataset values ('{car_name}','{brand}', '{model}',{vehicle_age},{km_driven},'{seller_type}','{fuel_type}','{transmission_type}',{mileage},{engine},{max_power},{seats},{selling_price});"""
        cursor = conn.cursor()
        cursor.execute(query)
    conn.commit()

except Exception as e:
    print(e)
else:
    print('connected')
    print("table created successfully")
finally:
    conn.close()
# Out:
# connected
# table created successfully

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0          Dealer       CNG            Manual    26.83     796       38.4
# 1          Dealer       CNG            Manual    26.83     796       38.4
# 2          Dealer       CNG            Manual    26.83     796       38.4
# 3          Dealer       CNG            Manual    26.83     796       38.4
# 4      Individual       CNG            Manual    26.83     796       38.4
# ...           ...       ...               ...      ...     ...        ...
# 15406      Dealer    Petrol         Automatic     8.60    5998      552.0
# 15407  Individual    Petrol         Automatic    10.20    6592      563.0
# 15408      Dealer    Petrol         Automatic     6.00    5998      600.0
# 15409      Dealer    Petrol         Automatic     4.00    3855      601.0
# 15410      Dealer    Petrol         Automatic     9.50    5998      626.0
#
#        seats  selling_price
# 0          5         235000
# 1          5         185000
# 2          5         150000
# 3          5         172000
# 4          5         125000
# ...      ...            ...
# 15406      4        8100000
# 15407      4       24200000
# 15408      5        5200000
# 15409      4       39500000
# 15410      4       14500000
#
# [15411 rows x 13 columns]

# %%
df.head() # top 5 records
# Out:
#       car_name   brand model  vehicle_age  km_driven seller_type fuel_type  \
# 0  Maruti Alto  Maruti  Alto            9      53800      Dealer       CNG
# 1  Maruti Alto  Maruti  Alto           11      11000      Dealer       CNG
# 2  Maruti Alto  Maruti  Alto           11      80000      Dealer       CNG
# 3  Maruti Alto  Maruti  Alto           10      57000      Dealer       CNG
# 4  Maruti Alto  Maruti  Alto           11      72000  Individual       CNG
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    26.83     796       38.4      5         235000
# 1            Manual    26.83     796       38.4      5         185000
# 2            Manual    26.83     796       38.4      5         150000
# 3            Manual    26.83     796       38.4      5         172000
# 4            Manual    26.83     796       38.4      5         125000

# %%
df.tail() # bottom 5 records
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 15406      Dealer    Petrol         Automatic      8.6    5998      552.0
# 15407  Individual    Petrol         Automatic     10.2    6592      563.0
# 15408      Dealer    Petrol         Automatic      6.0    5998      600.0
# 15409      Dealer    Petrol         Automatic      4.0    3855      601.0
# 15410      Dealer    Petrol         Automatic      9.5    5998      626.0
#
#        seats  selling_price
# 15406      4        8100000
# 15407      4       24200000
# 15408      5        5200000
# 15409      4       39500000
# 15410      4       14500000

# %%
df.sample(10)
# Out:
#                car_name     brand    model  vehicle_age  km_driven  \
# 12816     Hyundai Verna   Hyundai    Verna            9     115721
# 6126        Hyundai i20   Hyundai      i20            2       5000
# 10930     Mahindra Thar  Mahindra     Thar            4      15000
# 14980          Volvo XC     Volvo       XC            7      24000
# 12030  Mahindra Scorpio  Mahindra  Scorpio            3      57000
# 7089       Maruti Swift    Maruti    Swift            5      65000
# 1999        Maruti Alto    Maruti     Alto            7      53000
# 124         Maruti Alto    Maruti     Alto           15     120000
# 9665         Honda Jazz     Honda     Jazz            5      38739
# 12865     Hyundai Verna   Hyundai    Verna            7      72000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 12816      Dealer    Diesel            Manual    22.32    1582     126.32
# 6126   Individual    Petrol            Manual    18.60    1197      81.86
# 10930  Individual    Diesel            Manual    16.55    2498     105.00
# 14980      Dealer    Diesel         Automatic    11.10    2400     200.00
# 12030      Dealer    Diesel            Manual    15.40    1997     120.00
# 7089       Dealer    Petrol            Manual    18.60    1197      85.80
# 1999       Dealer    Petrol            Manual    23.95     998      67.05
# 124    Individual    Petrol            Manual    19.70     796      46.30
# 9665       Dealer    Diesel            Manual    27.30    1498      98.60
# 12865      Dealer    Diesel            Manual    22.32    1582     126.32
#
#        seats  selling_price
# 12816      5         495000
# 6126       5         624000
# 10930      6         850000
# 14980      7        2400000
# 12030      7        1035000
# 7089       5         465000
# 1999       5         290000
# 124        5         150000
# 9665       5         575000
# 12865      5         475000

# %%
df.shape
# Out:
# (15411, 13)

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
pd.Categorical(df['car_name'])
# Out:
# ['Maruti Alto', 'Maruti Alto', 'Maruti Alto', 'Maruti Alto', 'Maruti Alto', ..., 'Bentley Continental', 'Rolls-Royce Ghost', 'Bentley Continental', 'Ferrari GTC4Lusso', 'Bentley Continental']
# Length: 15411
# Categories (121, object): ['Audi A4', 'Audi A6', 'Audi A8', 'Audi Q7', ..., 'Volvo S90', 'Volvo XC', 'Volvo XC60', 'Volvo XC90']

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.isnull().sum()/df.isnull().count()
# Out:
# car_name             0.0
# brand                0.0
# model                0.0
# vehicle_age          0.0
# km_driven            0.0
# seller_type          0.0
# fuel_type            0.0
# transmission_type    0.0
# mileage              0.0
# engine               0.0
# max_power            0.0
# seats                0.0
# selling_price        0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#         vehicle_age     km_driven       mileage        engine     max_power  \
# count  15411.000000  1.541100e+04  15411.000000  15411.000000  15411.000000
# mean       6.036338  5.561648e+04     19.701151   1486.057751    100.588254
# std        3.013291  5.161855e+04      4.171265    521.106696     42.972979
# min        0.000000  1.000000e+02      4.000000    793.000000     38.400000
# 25%        4.000000  3.000000e+04     17.000000   1197.000000     74.000000
# 50%        6.000000  5.000000e+04     19.670000   1248.000000     88.500000
# 75%        8.000000  7.000000e+04     22.700000   1582.000000    117.300000
# max       29.000000  3.800000e+06     33.540000   6592.000000    626.000000
#
#               seats  selling_price
# count  15411.000000   1.541100e+04
# mean       5.325482   7.749711e+05
# std        0.807628   8.941284e+05
# min        0.000000   4.000000e+04
# 25%        5.000000   3.850000e+05
# 50%        5.000000   5.560000e+05
# 75%        5.000000   8.250000e+05
# max        9.000000   3.950000e+07

# %%
df.describe(include='object')
# Out:
#            car_name   brand  model seller_type fuel_type transmission_type
# count         15411   15411  15411       15411     15411             15411
# unique          121      32    120           3         5                 2
# top     Hyundai i20  Maruti    i20      Dealer    Petrol            Manual
# freq            906    4992    906        9539      7643             12225

# %% [markdown]
# # observations=>
# - hyundai i20 => 906

# %% [markdown]
# # EDA

# %%
df['engine'].dtype != 'O'
# Out:
# True

# %%
df['brand'].dtype !='O'
# Out:
# False

# %%
# split numerical and categorical features

numerical_features= [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
print(f"there are {len(numerical_features)} numerical features named: {numerical_features}")
print(f"there are {len(categorical_features)} categorical features named: {categorical_features}")
# Out:
# there are 7 numerical features named: ['vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power', 'seats', 'selling_price']
# there are 6 categorical features named: ['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']
